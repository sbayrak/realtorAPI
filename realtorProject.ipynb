# %%
import pandas as pd
import requests

# %%
url = "https://realtor.p.rapidapi.com/properties/v2/list-sold"

querystring = {"city":"New York City","offset":"0","state_code":"NY","limit":"200","sort":"sold_date"}

headers = {
    'x-rapidapi-key': "b1a61ad468mshb91fbd667f933f2p13d8d9jsn8beeabc3362a",
    'x-rapidapi-host': "realtor.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %% [markdown]
# ## Functions

# %%
def api_property_list_for_sale(api_key, city, state, limit=200):
  # url for api
  url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

  # enter parameters
  querystring = {
    "sort":"relevance","city":city,"offset":"0","limit":limit,"state_code":state 
  }

  # header
  headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': api_key
  }

  # response
  response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json() # json format

# %%
def api_property_list_for_sale_propType(api_key, city, state, prop_type, limit=200):
  # url for api
  url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

  # enter parameters
  querystring = {
    "sort":"relevance","city":city,"offset":"0","limit":limit,"state_code":state, "prop_type":prop_type 
  }

  # header
  headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': api_key
  }

  # response
  response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json() # json format

# %%
def api_property_list_for_sale_bedsMin(api_key, city, state, beds_min, limit=200):
  # url for api
  url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

  # enter parameters
  querystring = {"city":city,"limit":"200","offset":"0","state_code":state,"beds_min":beds_min,"sort":"relevance"}

  # header
  headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': api_key
  }

  # response
  response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json() # json format

# %%
def api_property_list_for_sale_bathsMin(api_key, city, state, baths_min, limit=200):
  # url for api
  url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

  # enter parameters
  querystring = {"city":city,"limit":"200","offset":"0","state_code":state,"sort":"relevance","baths_min":baths_min}

  # header
  headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': api_key
  }

  # response
  response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json() # json format

# %%
def api_property_list_for_sale_priceMin(api_key, city, state, price_min, limit=200):
  # url for api
  url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

  # enter parameters
  querystring = {"city":city,"limit":"200","offset":"0","state_code":state,"sort":"relevance","price_min":price_min}

  # header
  headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': api_key
  }

  # response
  response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json() # json format

# %%
def api_property_list_for_rent_isCatsAllowed(api_key, city, state, allows_cats, limit=200):
  # url for api
  url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

  # enter parameters
  querystring = {"city":city,"state_code":state,"limit":"200","offset":"0","sort":"relevance","allows_cats":allows_cats}

  # header
  headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': api_key
  }

  # response
  response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json() # json format

# %%
def api_property_similar_list(api_key, city, state, property_id, limit=200):
    url = "https://realtor.p.rapidapi.com/properties/v2/list-similar-homes"

    querystring = {"property_id":property_id}

    headers = {
        'x-rapidapi-key': "b1a61ad468mshb91fbd667f933f2p13d8d9jsn8beeabc3362a",
        'x-rapidapi-host': "realtor.p.rapidapi.com"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    return response.json() # json format

# %%
def process_similar_list(response_json):
    """
    Process the list for sale API response.

    Convert each listing to a dataframe, append to a list, and concatenate to one dataframe.

    Parameters
    ----------
    @response_json [dictionary]: API response for list for sale

    Returns
    -------
    [dataframe] Dataframe of all list for sale responses

    """

    # empty dataframe
    dataframe_list = []

    # iterate through each for sale listing
    for l in response_json['data']['home']['related_homes']['results']:

        # convert each listing to dataframe
        _temp_df = pd.DataFrame.from_dict(l, orient='index').T

        # append to dataframe list for all listings
        dataframe_list.append(_temp_df)

    # concatenate all dataframes, for missing col values enter null value
    return pd.concat(dataframe_list, axis=0, ignore_index=True, sort=False)

# %%
def process_list_for_sale_response(response_json):
    """
    Process the list for sale API response.

    Convert each listing to a dataframe, append to a list, and concatenate to one dataframe.

    Parameters
    ----------
    @response_json [dictionary]: API response for list for sale

    Returns
    -------
    [dataframe] Dataframe of all list for sale responses

    """

    # empty dataframe
    dataframe_list = []

    # iterate through each for sale listing
    for l in response_json['properties']:

        # convert each listing to dataframe
        _temp_df = pd.DataFrame.from_dict(l, orient='index').T

        # append to dataframe list for all listings
        dataframe_list.append(_temp_df)

    # concatenate all dataframes, for missing col values enter null value
    return pd.concat(dataframe_list, axis=0, ignore_index=True, sort=False)

# %% [markdown]
# ## Variables

# %%
# CONSTANT VARIABLES
realtor_api_key = "b1a61ad468mshb91fbd667f933f2p13d8d9jsn8beeabc3362a"
city = "Newark"
state = "NJ"
prop_type = "single_family"
beds_min = "1"
baths_min = "1"

# %% [markdown]
# ## Data: API Property List for Sale

# %%
property_list_for_sale_response = api_property_list_for_sale(api_key=realtor_api_key, 
                                                             city=city, 
                                                             state=state,  
                                                             limit=200)

# %%
property_list_for_sale_response.head()

# %%
url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

querystring = {"city":"New York City","limit":"200","offset":"0","state_code":"NY","sort":"relevance"}

headers = {
    'x-rapidapi-key': "b1a61ad468mshb91fbd667f933f2p13d8d9jsn8beeabc3362a",
    'x-rapidapi-host': "realtor.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)

# %%
df_properties_for_sale_raw = process_list_for_sale_response(response_json=property_list_for_sale_response)
df_properties_for_sale_raw
# Out:
#      property_id  listing_id  \
# 0    M9444136833  2923872474
# 1    M9992508471  2923870559
# 2    M9601580407  2923869918
# 3    M9419250335  2923868430
# 4    M9996598186  2923866436
# ..           ...         ...
# 195  M9219494598  2922844322
# 196  M9774081520  2922843433
# 197  M5119909947  2922835434
# 198  M5830389176  2922826421
# 199  M6152143324  2922822940
#
#                                            rdc_web_url      prop_type  \
# 0    https://www.realtor.com/realestateandhomes-det...   multi_family
# 1    https://www.realtor.com/realestateandhomes-det...   multi_family
# 2    https://www.realtor.com/realestateandhomes-det...   multi_family
# 3    https://www.realtor.com/realestateandhomes-det...   multi_family
# 4    https://www.realtor.com/realestateandhomes-det...   multi_family
# ..                                                 ...            ...
# 195  https://www.realtor.com/realestateandhomes-det...   multi_family
# 196  https://www.realtor.com/realestateandhomes-det...          condo
# 197  https://www.realtor.com/realestateandhomes-det...  single_family
# 198  https://www.realtor.com/realestateandhomes-det...   multi_family
# 199  https://www.realtor.com/realestateandhomes-det...   multi_family
#
#                                                address  \
# 0    {'city': 'Newark', 'line': '184 Lincoln Ave Un...
# 1    {'city': 'Newark', 'line': '748 S 16th St', 'p...
# 2    {'city': 'Newark', 'line': '748 S 16th St', 'p...
# 3    {'city': 'Newark', 'line': '264 Lehigh Ave', '...
# 4    {'city': 'Newark', 'line': '179 Mapes Ave', 'p...
# ..                                                 ...
# 195  {'city': 'Newark', 'line': '8-10 Goble St', 'p...
# 196  {'city': 'Newark', 'line': '56-60 Ferguson St ...
# 197  {'city': 'Newark', 'line': '246 N 6th St', 'po...
# 198  {'city': 'Newark', 'line': '70 Cutler St', 'po...
# 199  {'city': 'Newark', 'line': '104 Broad St', 'po...
#
#                                               branding prop_status   price  \
# 0    {'listing_office': {'list_item': {'name': 'Exi...    for_sale  279000
# 1    {'listing_office': {'list_item': {'name': 'Sig...    for_sale  335000
# 2    {'listing_office': {'list_item': {'name': 'Sig...    for_sale  335000
# 3    {'listing_office': {'list_item': {'name': 'Col...    for_sale  475000
# 4    {'listing_office': {'list_item': {'name': 'Col...    for_sale  475000
# ..                                                 ...         ...     ...
# 195  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  650000
# 196  {'listing_office': {'list_item': {'name': 'COM...    for_sale  275000
# 197  {'listing_office': {'list_item': {'name': 'RE/...    for_sale   89000
# 198  {'listing_office': {'list_item': {'name': 'Re/...    for_sale  315000
# 199  {'listing_office': {'list_item': {'name': 'ONE...    for_sale  559900
#
#     baths_full baths  ... rank  \
# 0            3     3  ...    1
# 1            3     3  ...    2
# 2            3     3  ...    3
# 3            3     3  ...    4
# 4            3     5  ...    5
# ..         ...   ...  ...  ...
# 195          4     5  ...   24
# 196          2     2  ...   25
# 197          1     1  ...   26
# 198          4     4  ...   27
# 199          5     5  ...   28
#
#                                          list_tracking  \
# 0    type|property|data|prop_id|9444136833|list_id|...
# 1    type|property|data|prop_id|9992508471|list_id|...
# 2    type|property|data|prop_id|9601580407|list_id|...
# 3    type|property|data|prop_id|9419250335|list_id|...
# 4    type|property|data|prop_id|9996598186|list_id|...
# ..                                                 ...
# 195  type|property|data|prop_id|9219494598|list_id|...
# 196  type|property|data|prop_id|9774081520|list_id|...
# 197  type|property|data|prop_id|5119909947|list_id|...
# 198  type|property|data|prop_id|5830389176|list_id|...
# 199  type|property|data|prop_id|6152143324|list_id|...
#
#                              lot_size  \
# 0    {'size': 34848, 'units': 'sqft'}
# 1                                 NaN
# 2     {'size': 2614, 'units': 'sqft'}
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 195                               NaN
# 196  {'size': 28750, 'units': 'sqft'}
# 197   {'size': 1742, 'units': 'sqft'}
# 198   {'size': 2614, 'units': 'sqft'}
# 199   {'size': 3049, 'units': 'sqft'}
#
#                                                    mls  \
# 0    {'name': 'GardenState', 'id': '3680966', 'plan...
# 1    {'name': 'NewJerseyMLS', 'id': '20049737', 'pl...
# 2    {'name': 'GardenState', 'id': '3680956', 'plan...
# 3    {'name': 'NewJerseyMLS', 'id': '20049734', 'pl...
# 4    {'name': 'NewJerseyMLS', 'id': '20049729', 'pl...
# ..                                                 ...
# 195  {'name': 'NewJerseyMLS', 'id': '20045457', 'pl...
# 196  {'name': 'GardenState', 'id': '3674684', 'plan...
# 197  {'name': 'Monmouth', 'id': '22038565', 'plan_i...
# 198  {'name': 'GardenState', 'id': '3674601', 'plan...
# 199  {'name': 'GardenState', 'id': '3674578', 'plan...
#
#                                              thumbnail baths_half  \
# 0                                                  NaN        NaN
# 1    https://ap.rdcpix.com/8214d89cf3914f6294ea2abe...        NaN
# 2    https://ap.rdcpix.com/f9eecb97b944059aeadb4f0e...        NaN
# 3    https://ap.rdcpix.com/782c43b1b4d5f643a7805d5d...        NaN
# 4    https://ap.rdcpix.com/31853030f5ada499acb4e73e...          2
# ..                                                 ...        ...
# 195  https://ap.rdcpix.com/b3efc56cc8e0dece28d77e8b...          1
# 196  https://ap.rdcpix.com/252a3c4ac11ead4bf348b780...        NaN
# 197  https://ap.rdcpix.com/a9effab27b160075c5f809b1...        NaN
# 198  https://ap.rdcpix.com/81866f025ed2d32e4993a27b...        NaN
# 199  https://ap.rdcpix.com/2b52ea33d8123df9ad6d5a2f...        NaN
#
#                        building_size prop_sub_type virtual_tour open_houses
# 0                                NaN           NaN          NaN         NaN
# 1                                NaN           NaN          NaN         NaN
# 2                                NaN           NaN          NaN         NaN
# 3                                NaN           NaN          NaN         NaN
# 4                                NaN           NaN          NaN         NaN
# ..                               ...           ...          ...         ...
# 195                              NaN           NaN          NaN         NaN
# 196  {'size': 1131, 'units': 'sqft'}        condos          NaN         NaN
# 197                              NaN           NaN          NaN         NaN
# 198                              NaN           NaN          NaN         NaN
# 199                              NaN           NaN          NaN         NaN
#
# [200 rows x 28 columns]

# %%
#df_properties_for_sale_raw['price'].mean()

# %%
#df_properties_for_sale_raw

# %%
#df_properties_for_sale_raw['price'][:10].plot(kind='bar')

# %%
property_similar_list = api_property_similar_list(api_key=realtor_api_key, 
                                                             city=city, 
                                                             state=state,
                                                            property_id = "M6152143324",
                                                             limit=200)
#M6152143324

# %%
property_similar_list
# Out:
# {'data': {'home': {'related_homes': {'count': 20,
#     'results': [{'property_id': '5824614757',
#       'list_price': 319900,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/33-35-Freeman-St-Apt-A2_Newark_NJ_07105_M58246-14757',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2920126996',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/3f3b3d5f8988dcc963e69092566a6509l-m3881722824xd-w300_h300_q80.jpg'},
#       'description': {'baths': 2,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 3,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '33 35 Freeman St Apt A 2'}}},
#      {'property_id': '6384080373',
#       'list_price': 430000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/792-S-14th-St_Newark_NJ_07108_M63840-80373',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2922538322',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/86725cf11c970f555a943668ecd66202l-m2295473741xd-w300_h300_q80.jpg'},
#       'description': {'baths': 4,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 6,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '792 S 14th St'}}},
#      {'property_id': '9389655483',
#       'list_price': 599000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/445-S-18th-St_Newark_NJ_07103_M93896-55483',
#       'flags': {'is_contingent': None,
#        'is_new_construction': True,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': True},
#       'status': 'for_sale',
#       'listing_id': '2923628061',
#       'primary_photo': {'href': None},
#       'description': {'baths': 5,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 8,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '445 S 18th St'}}},
#      {'property_id': '6143908590',
#       'list_price': 299900,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/70-Alexander-St_Newark_NJ_07106_M61439-08590',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2920822698',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/7ae1b93319cb3b47e552d1f8d5f71b1al-m2067983917xd-w300_h300_q80.jpg'},
#       'description': {'baths': 2,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 4,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '70 Alexander St'}}},
#      {'property_id': '6867299321',
#       'list_price': 490000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/41-Chester-Ave_Newark_NJ_07104_M68672-99321',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2922334727',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/4aae672a0e137fd5c32db25a973b83c7l-m2963834195xd-w300_h300_q80.jpg'},
#       'description': {'baths': 4,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 10,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '41 Chester Ave'}}},
#      {'property_id': '9199496537',
#       'list_price': 439000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/174-S-12th-St_Newark_NJ_07107_M91994-96537',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2913576271',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/1e3705551698916e2a4ee6353899a466l-m1419187545xd-w300_h300_q80.jpg'},
#       'description': {'baths': 4,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 6,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '174 S 12 Th St'}}},
#      {'property_id': '9259860122',
#       'list_price': 324900,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/243-Summer-Ave_Newark_NJ_07104_M92598-60122',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2922882981',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/1fc1f6398e9de7ae722bd7d97dca95dcl-m338735412xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 5,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '243 Summer Ave'}}},
#      {'property_id': '9294451440',
#       'list_price': 475000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/66-68-Vermont-Ave_Newark_NJ_07106_M92944-51440',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2920362802',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/82fe60b8e62d47183f2e281be92cb98el-m1223584816xd-w300_h300_q80.jpg'},
#       'description': {'baths': 5,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 11,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '66 68 Vermont Ave'}}},
#      {'property_id': '9211014479',
#       'list_price': 375000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/100-Cossio-Dr_Newark_NJ_07103_M92110-14479',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2922760054',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/326ff953b0227097022f71c77d956d9cl-m1947633971xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 2,
#        'sqft': 1896},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '100 Cossio Dr'}}},
#      {'property_id': '6220765177',
#       'list_price': 410000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/242-244-Schley-St_Newark-City_NJ_07112_M62207-65177',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2913237588',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/30850f3c37499dfd8fa716dc71254317l-m3873813386xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 7,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '242 244 Schley St'}}},
#      {'property_id': '6792038014',
#       'list_price': 225000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/364-Bergen-St_Newark_NJ_07103_M67920-38014',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2921899857',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/19ef0bfe13eb8041d2d5afbf03941e1cl-m1862811651xd-w300_h300_q80.jpg'},
#       'description': {'baths': 2,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 3,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '364 Bergen St'}}},
#      {'property_id': '9496901971',
#       'list_price': 160000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/96-Forest-Hill-Pkwy_Newark_NJ_07104_M94969-01971',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2923054980',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/2d7cc30e1d661248b02e5b72709ef90bl-m480665957xd-w300_h300_q80.jpg'},
#       'description': {'baths': 1,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 1,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '96 Forest Hill Pkwy'}}},
#      {'property_id': '5105849314',
#       'list_price': 245000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/44-Isabella-Ave_Newark_NJ_07106_M51058-49314',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2921407253',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/badf5580776a7ac6f6a7653993ab1993l-m1876320346xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 4,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '44 Isabella Ave'}}},
#      {'property_id': '9184457895',
#       'list_price': 215000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/18-Ashby-Ln_Newark_NJ_07103_M91844-57895',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2923207052',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/203d2d8a8b17c3e766ba2faf82e70ab4l-m88156553xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 2,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '18 Ashby Ln'}}},
#      {'property_id': '5395477223',
#       'list_price': 420000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/924-Bergen-St_Newark_NJ_07112_M53954-77223',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2922419249',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/a74f3f3ecc95bcd262f09dd96d31b634l-m3989538753xd-w300_h300_q80.jpg'},
#       'description': {'baths': 5,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 6,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '924 Bergen St'}}},
#      {'property_id': '9699943550',
#       'list_price': 320000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/19-Honiss-Pl_Newark_NJ_07104_M96999-43550',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2923082236',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/5b0bfb5b3f950053984e09502401b0ddl-m3311144587xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 3,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '19 Honiss Pl'}}},
#      {'property_id': '6318872190',
#       'list_price': 375000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/114-Chambers-St_Newark_NJ_07105_M63188-72190',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2923185794',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/b7fd5c28b31f8a3661ce462b0452653fl-m2227227866xd-w300_h300_q80.jpg'},
#       'description': {'baths': 2,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 3,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '114 Chambers St'}}},
#      {'property_id': '6109842444',
#       'list_price': 349000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/33-Emmet-St_Newark_NJ_07114_M61098-42444',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2918063056',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/27be573d4b0c002883e0bf92d28188b7l-m4106323747xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 4,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '33 Emmet St'}}},
#      {'property_id': '5695023865',
#       'list_price': 439000,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/9-Nichols-St_Newark_NJ_07105_M56950-23865',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2921433241',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/610654faf7dd56ec796fc60bd377e6c7l-m1313488383xd-w300_h300_q80.jpg'},
#       'description': {'baths': 3,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 4,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '9 Nichols St'}}},
#      {'property_id': '9665841219',
#       'list_price': 849900,
#       'href': 'https://www.realtor.com/realestateandhomes-detail/44-46-Mlk-Blvd_Newark_NJ_07104_M96658-41219',
#       'flags': {'is_contingent': None,
#        'is_new_construction': None,
#        'is_pending': None,
#        'is_foreclosure': None,
#        'is_new_listing': False},
#       'status': 'for_sale',
#       'listing_id': '2916793079',
#       'primary_photo': {'href': 'https://ap.rdcpix.com/fe70d8492008733cc84afbcf68d68b5cl-m3302409185xd-w300_h300_q80.jpg'},
#       'description': {'baths': 5,
#        'baths_full': None,
#        'baths_half': None,
#        'beds': 9,
#        'sqft': None},
#       'location': {'address': {'city': 'Newark',
#         'country': 'usa',
#         'line': '44 46 Mlk Blvd'}}}],
#     'impression_token': {'product': 'ir_platform',
#      'type': 'impression_token',
#      'api_route': 'similarhomestradeoffs',
#      'module_name': 'SimilarHomes',
#      'algo_name': 'MLBased',
#      'algo_version': '1.0',
#      'model_name': 'LightGBM',
#      'module_type': 'fs-to-fs',
#      'model_version': '1.0',
#      'impression_id': 'cki5wba2442mf01qn5kcchdwg',
#      'recommendations_count': 20,
#      'client_id': 'rdc-x-hestia.graphql.server'}}}}}

# %%
df_properties_similar_list = process_similar_list(response_json=property_similar_list)
df_properties_similar_list
# Out:
#    property_id list_price                                               href  \
# 0   5824614757     319900  https://www.realtor.com/realestateandhomes-det...
# 1   6384080373     430000  https://www.realtor.com/realestateandhomes-det...
# 2   9389655483     599000  https://www.realtor.com/realestateandhomes-det...
# 3   6143908590     299900  https://www.realtor.com/realestateandhomes-det...
# 4   6867299321     490000  https://www.realtor.com/realestateandhomes-det...
# 5   9199496537     439000  https://www.realtor.com/realestateandhomes-det...
# 6   9259860122     324900  https://www.realtor.com/realestateandhomes-det...
# 7   9294451440     475000  https://www.realtor.com/realestateandhomes-det...
# 8   9211014479     375000  https://www.realtor.com/realestateandhomes-det...
# 9   6220765177     410000  https://www.realtor.com/realestateandhomes-det...
# 10  6792038014     225000  https://www.realtor.com/realestateandhomes-det...
# 11  9496901971     160000  https://www.realtor.com/realestateandhomes-det...
# 12  5105849314     245000  https://www.realtor.com/realestateandhomes-det...
# 13  9184457895     215000  https://www.realtor.com/realestateandhomes-det...
# 14  5395477223     420000  https://www.realtor.com/realestateandhomes-det...
# 15  9699943550     320000  https://www.realtor.com/realestateandhomes-det...
# 16  6318872190     375000  https://www.realtor.com/realestateandhomes-det...
# 17  6109842444     349000  https://www.realtor.com/realestateandhomes-det...
# 18  5695023865     439000  https://www.realtor.com/realestateandhomes-det...
# 19  9665841219     849900  https://www.realtor.com/realestateandhomes-det...
#
#                                                 flags    status  listing_id  \
# 0   {'is_contingent': None, 'is_new_construction':...  for_sale  2920126996
# 1   {'is_contingent': None, 'is_new_construction':...  for_sale  2922538322
# 2   {'is_contingent': None, 'is_new_construction':...  for_sale  2923628061
# 3   {'is_contingent': None, 'is_new_construction':...  for_sale  2920822698
# 4   {'is_contingent': None, 'is_new_construction':...  for_sale  2922334727
# 5   {'is_contingent': None, 'is_new_construction':...  for_sale  2913576271
# 6   {'is_contingent': None, 'is_new_construction':...  for_sale  2922882981
# 7   {'is_contingent': None, 'is_new_construction':...  for_sale  2920362802
# 8   {'is_contingent': None, 'is_new_construction':...  for_sale  2922760054
# 9   {'is_contingent': None, 'is_new_construction':...  for_sale  2913237588
# 10  {'is_contingent': None, 'is_new_construction':...  for_sale  2921899857
# 11  {'is_contingent': None, 'is_new_construction':...  for_sale  2923054980
# 12  {'is_contingent': None, 'is_new_construction':...  for_sale  2921407253
# 13  {'is_contingent': None, 'is_new_construction':...  for_sale  2923207052
# 14  {'is_contingent': None, 'is_new_construction':...  for_sale  2922419249
# 15  {'is_contingent': None, 'is_new_construction':...  for_sale  2923082236
# 16  {'is_contingent': None, 'is_new_construction':...  for_sale  2923185794
# 17  {'is_contingent': None, 'is_new_construction':...  for_sale  2918063056
# 18  {'is_contingent': None, 'is_new_construction':...  for_sale  2921433241
# 19  {'is_contingent': None, 'is_new_construction':...  for_sale  2916793079
#
#                                         primary_photo  \
# 0   {'href': 'https://ap.rdcpix.com/3f3b3d5f8988dc...
# 1   {'href': 'https://ap.rdcpix.com/86725cf11c970f...
# 2                                      {'href': None}
# 3   {'href': 'https://ap.rdcpix.com/7ae1b93319cb3b...
# 4   {'href': 'https://ap.rdcpix.com/4aae672a0e137f...
# 5   {'href': 'https://ap.rdcpix.com/1e370555169891...
# 6   {'href': 'https://ap.rdcpix.com/1fc1f6398e9de7...
# 7   {'href': 'https://ap.rdcpix.com/82fe60b8e62d47...
# 8   {'href': 'https://ap.rdcpix.com/326ff953b02270...
# 9   {'href': 'https://ap.rdcpix.com/30850f3c37499d...
# 10  {'href': 'https://ap.rdcpix.com/19ef0bfe13eb80...
# 11  {'href': 'https://ap.rdcpix.com/2d7cc30e1d6612...
# 12  {'href': 'https://ap.rdcpix.com/badf5580776a7a...
# 13  {'href': 'https://ap.rdcpix.com/203d2d8a8b17c3...
# 14  {'href': 'https://ap.rdcpix.com/a74f3f3ecc95bc...
# 15  {'href': 'https://ap.rdcpix.com/5b0bfb5b3f9500...
# 16  {'href': 'https://ap.rdcpix.com/b7fd5c28b31f8a...
# 17  {'href': 'https://ap.rdcpix.com/27be573d4b0c00...
# 18  {'href': 'https://ap.rdcpix.com/610654faf7dd56...
# 19  {'href': 'https://ap.rdcpix.com/fe70d849200873...
#
#                                           description  \
# 0   {'baths': 2, 'baths_full': None, 'baths_half':...
# 1   {'baths': 4, 'baths_full': None, 'baths_half':...
# 2   {'baths': 5, 'baths_full': None, 'baths_half':...
# 3   {'baths': 2, 'baths_full': None, 'baths_half':...
# 4   {'baths': 4, 'baths_full': None, 'baths_half':...
# 5   {'baths': 4, 'baths_full': None, 'baths_half':...
# 6   {'baths': 3, 'baths_full': None, 'baths_half':...
# 7   {'baths': 5, 'baths_full': None, 'baths_half':...
# 8   {'baths': 3, 'baths_full': None, 'baths_half':...
# 9   {'baths': 3, 'baths_full': None, 'baths_half':...
# 10  {'baths': 2, 'baths_full': None, 'baths_half':...
# 11  {'baths': 1, 'baths_full': None, 'baths_half':...
# 12  {'baths': 3, 'baths_full': None, 'baths_half':...
# 13  {'baths': 3, 'baths_full': None, 'baths_half':...
# 14  {'baths': 5, 'baths_full': None, 'baths_half':...
# 15  {'baths': 3, 'baths_full': None, 'baths_half':...
# 16  {'baths': 2, 'baths_full': None, 'baths_half':...
# 17  {'baths': 3, 'baths_full': None, 'baths_half':...
# 18  {'baths': 3, 'baths_full': None, 'baths_half':...
# 19  {'baths': 5, 'baths_full': None, 'baths_half':...
#
#                                              location
# 0   {'address': {'city': 'Newark', 'country': 'usa...
# 1   {'address': {'city': 'Newark', 'country': 'usa...
# 2   {'address': {'city': 'Newark', 'country': 'usa...
# 3   {'address': {'city': 'Newark', 'country': 'usa...
# 4   {'address': {'city': 'Newark', 'country': 'usa...
# 5   {'address': {'city': 'Newark', 'country': 'usa...
# 6   {'address': {'city': 'Newark', 'country': 'usa...
# 7   {'address': {'city': 'Newark', 'country': 'usa...
# 8   {'address': {'city': 'Newark', 'country': 'usa...
# 9   {'address': {'city': 'Newark', 'country': 'usa...
# 10  {'address': {'city': 'Newark', 'country': 'usa...
# 11  {'address': {'city': 'Newark', 'country': 'usa...
# 12  {'address': {'city': 'Newark', 'country': 'usa...
# 13  {'address': {'city': 'Newark', 'country': 'usa...
# 14  {'address': {'city': 'Newark', 'country': 'usa...
# 15  {'address': {'city': 'Newark', 'country': 'usa...
# 16  {'address': {'city': 'Newark', 'country': 'usa...
# 17  {'address': {'city': 'Newark', 'country': 'usa...
# 18  {'address': {'city': 'Newark', 'country': 'usa...
# 19  {'address': {'city': 'Newark', 'country': 'usa...
